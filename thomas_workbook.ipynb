# %% [markdown]
# This is where my work lives.

# %%
import pandas as pd

# %%
#Read in each month csv

jan = pd.read_csv('Resources/202001-citibike-tripdata.csv')
feb = pd.read_csv('Resources/202002-citibike-tripdata.csv')
mar = pd.read_csv('Resources/202003-citibike-tripdata.csv')
apr = pd.read_csv('Resources/202004-citibike-tripdata.csv')
may = pd.read_csv('Resources/202005-citibike-tripdata.csv')
jun = pd.read_csv('Resources/202006-citibike-tripdata.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f0de47514b99> in <module>
#       4 feb = pd.read_csv('Resources/202002-citibike-tripdata.csv')
#       5 mar = pd.read_csv('Resources/202003-citibike-tripdata.csv')
# ----> 6 apr = pd.read_csv('Resources/202004-citibike-tripdata.csv')
#       7 may = pd.read_csv('Resources/202005-citibike-tripdata.csv')
#       8 jun = pd.read_csv('Resources/202006-citibike-tripdata.csv')
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     540
#     541
# --> 542 def is_categorical_dtype(arr_or_dtype) -> bool:
#     543     """
#     544     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
#For each month, append the next month, then drop all null values from the resulting data frame

jf = jan.append(feb)

jf.dropna()

jfm = jf.append(mar)

jfm.dropna()

jfma = jfm.append(apr)

jfma.dropna()

jfmam = jfma.append(may)

jfmam.dropna()

full_dataset = jfmam.append(jun)

full_dataset.dropna()

full_dataset.columns = ['tripduration', 'starttime', 'stoptime', 'start_stationid', 'start_stationname', 'start_stationlat', 'start_stationlon', 
             'end_stationid', 'end_stationname', 'end_stationlat', 'end_stationlon', 'bikeid', 'usertype', 'birthyear', 'gender']

# %%
#Split the start and stop time columns in two, then place the date values into a new column
datetime = full_dataset["starttime"].str.split(" ", n = 1, expand = True) 

full_dataset['startdate'] = datetime[0]

enddatetime = full_dataset["stoptime"].str.split(" ", n = 1, expand = True) 

full_dataset['stopdate'] = enddatetime[0]

# %%
#Get age by substrction birth year from 2020
full_dataset['age'] = 2020 - full_dataset['birthyear']

# %%
#Get time in minutes by dividing time in seconds by 60
full_dataset['duration(min)'] = round(full_dataset['tripduration']/60, 2)

full_dataset

# %%
del full_dataset['tripduration']
del full_dataset['starttime']
del full_dataset['stoptime']
del full_dataset['start_stationid']
del full_dataset['end_stationid']
del full_dataset['birthyear']

full_dataset
# Out:
#                    start_stationname  start_stationlat  start_stationlon  \
# 0                  E 2 St & Avenue A         40.723077        -73.985836
# 1        Central Park West & W 68 St         40.773407        -73.977825
# 2             Columbus Ave & W 72 St         40.777057        -73.978985
# 3               Halsey St & Broadway         40.685650        -73.915640
# 4                Grove St & Broadway         40.690470        -73.923511
# ...                              ...               ...               ...
# 1882268           E 20 St & Park Ave         40.738274        -73.987520
# 1882269              W 50 St & 9 Ave         40.763605        -73.989180
# 1882270              W 50 St & 9 Ave         40.763605        -73.989180
# 1882271    Stewart Ave & Johnson Ave         40.708690        -73.925870
# 1882272      DeKalb Ave & Hudson Ave         40.689888        -73.981013
#
#                    end_stationname  end_stationlat  end_stationlon  bikeid  \
# 0                  E 23 St & 1 Ave       40.736502      -73.978095   15162
# 1           Columbus Ave & W 95 St       40.791956      -73.968087   42861
# 2             31 Ave & Crescent St       40.765835      -73.926547   35989
# 3          Van Buren St & Broadway       40.692000      -73.926170   37548
# 4        Lewis Ave & Kosciuszko St       40.692371      -73.937054   39701
# ...                            ...             ...             ...     ...
# 1882268          6 Ave & Broome St       40.724308      -74.004730   21056
# 1882269            W 38 St & 8 Ave       40.754666      -73.991382   30164
# 1882270            W 38 St & 8 Ave       40.754666      -73.991382   43742
# 1882271    Greene Ave & Throop Ave       40.689493      -73.942061   15787
# 1882272       Johnson St & Gold St       40.694749      -73.983625   38767
#
#            usertype  gender   startdate    stopdate  age  duration(m)
# 0        Subscriber       2  2020-04-01  2020-04-01   30         8.90
# 1        Subscriber       1  2020-04-01  2020-04-01   46         8.82
# 2        Subscriber       1  2020-04-01  2020-04-01   38        24.80
# 3        Subscriber       1  2020-04-01  2020-04-01   24         5.68
# 4        Subscriber       1  2020-04-01  2020-04-01   43        36.77
# ...             ...     ...         ...         ...  ...          ...
# 1882268    Customer       2  2020-06-30  2020-07-01   27        11.42
# 1882269    Customer       0  2020-06-30  2020-07-01   51         7.43
# 1882270    Customer       1  2020-06-30  2020-07-01   34         7.32
# 1882271  Subscriber       1  2020-06-30  2020-07-01   26        14.83
# 1882272    Customer       1  2020-06-30  2020-07-01   30         7.22
#
# [4052925 rows x 13 columns]

# %%
clean_df = full_dataset[['duration(min)', 'startdate', 'stopdate', 'start_stationname', 'start_stationlat', 
             'start_stationlon', 'end_stationname', 'end_stationlat', 'end_stationlon', 
             'bikeid', 'usertype', 'age', 'gender' ]]

clean_df
# Out:
#          duration(m)   startdate    stopdate            start_stationname  \
# 0               8.90  2020-04-01  2020-04-01            E 2 St & Avenue A
# 1               8.82  2020-04-01  2020-04-01  Central Park West & W 68 St
# 2              24.80  2020-04-01  2020-04-01       Columbus Ave & W 72 St
# 3               5.68  2020-04-01  2020-04-01         Halsey St & Broadway
# 4              36.77  2020-04-01  2020-04-01          Grove St & Broadway
# ...              ...         ...         ...                          ...
# 1882268        11.42  2020-06-30  2020-07-01           E 20 St & Park Ave
# 1882269         7.43  2020-06-30  2020-07-01              W 50 St & 9 Ave
# 1882270         7.32  2020-06-30  2020-07-01              W 50 St & 9 Ave
# 1882271        14.83  2020-06-30  2020-07-01    Stewart Ave & Johnson Ave
# 1882272         7.22  2020-06-30  2020-07-01      DeKalb Ave & Hudson Ave
#
#          start_stationlat  start_stationlon            end_stationname  \
# 0               40.723077        -73.985836            E 23 St & 1 Ave
# 1               40.773407        -73.977825     Columbus Ave & W 95 St
# 2               40.777057        -73.978985       31 Ave & Crescent St
# 3               40.685650        -73.915640    Van Buren St & Broadway
# 4               40.690470        -73.923511  Lewis Ave & Kosciuszko St
# ...                   ...               ...                        ...
# 1882268         40.738274        -73.987520          6 Ave & Broome St
# 1882269         40.763605        -73.989180            W 38 St & 8 Ave
# 1882270         40.763605        -73.989180            W 38 St & 8 Ave
# 1882271         40.708690        -73.925870    Greene Ave & Throop Ave
# 1882272         40.689888        -73.981013       Johnson St & Gold St
#
#          end_stationlat  end_stationlon  bikeid    usertype  age  gender
# 0             40.736502      -73.978095   15162  Subscriber   30       2
# 1             40.791956      -73.968087   42861  Subscriber   46       1
# 2             40.765835      -73.926547   35989  Subscriber   38       1
# 3             40.692000      -73.926170   37548  Subscriber   24       1
# 4             40.692371      -73.937054   39701  Subscriber   43       1
# ...                 ...             ...     ...         ...  ...     ...
# 1882268       40.724308      -74.004730   21056    Customer   27       2
# 1882269       40.754666      -73.991382   30164    Customer   51       0
# 1882270       40.754666      -73.991382   43742    Customer   34       1
# 1882271       40.689493      -73.942061   15787  Subscriber   26       1
# 1882272       40.694749      -73.983625   38767    Customer   30       1
#
# [4052925 rows x 13 columns]
