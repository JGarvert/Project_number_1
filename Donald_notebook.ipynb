# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
jan = pd.read_csv('Resources/202001-citibike-tripdata.csv')
feb = pd.read_csv('Resources/202002-citibike-tripdata.csv')
mar = pd.read_csv('Resources/202003-citibike-tripdata.csv')
apr = pd.read_csv('Resources/202004-citibike-tripdata.csv')
may = pd.read_csv('Resources/202005-citibike-tripdata.csv')
jun = pd.read_csv('Resources/202006-citibike-tripdata.csv')

jan.head ()
# Out:
#    tripduration   Date                 Day of Week  Unnamed: 3 starttime  \
# 0           789  1-Jan  Wednesday, January 1, 2020         NaN   00:55.4
# 1          1541  1-Jan  Wednesday, January 1, 2020         NaN   01:08.1
# 2          1464  1-Jan  Wednesday, January 1, 2020         NaN   01:42.1
# 3           592  1-Jan  Wednesday, January 1, 2020         NaN   01:45.6
# 4           702  1-Jan  Wednesday, January 1, 2020         NaN   01:45.8
#
#    ConvertTime stoptime  start station id               start station name  \
# 0  12:00:55 AM  14:05.1               504                  1 Ave & E 16 St
# 1  12:01:08 AM  26:49.2              3423  West Drive & Prospect Park West
# 2  12:01:42 AM  26:07.0              3687                  E 33 St & 1 Ave
# 3  12:01:46 AM  11:38.2               346              Bank St & Hudson St
# 4  12:01:46 AM  13:28.2               372        Franklin Ave & Myrtle Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.732219               -73.981656           307.0
# 1               40.661063               -73.979453          3300.0
# 2               40.743227               -73.974498           259.0
# 3               40.736529               -74.006180           490.0
# 4               40.694546               -73.958014          3637.0
#
#             end station name  end station latitude  end station longitude  \
# 0      Canal St & Rutgers St             40.714275             -73.989900
# 1  Prospect Park West & 8 St             40.665147             -73.976376
# 2    South St & Whitehall St             40.701221             -74.012342
# 3            8 Ave & W 33 St             40.751551             -73.993934
# 4    Fulton St & Waverly Ave             40.683239             -73.965996
#
#     bikeid    usertype  birth year  gender
# 0  30326.0  Subscriber      1992.0     1.0
# 1  17105.0    Customer      1969.0     1.0
# 2  40177.0  Subscriber      1963.0     1.0
# 3  27690.0  Subscriber      1980.0     1.0
# 4  32583.0  Subscriber      1982.0     1.0

# %%
jf = jan.append(feb)

jf.dropna()

jfm = jf.append(mar)

jfm.dropna()

jfma = jfm.append(apr)

jfma.dropna()

jfmam = jfma.append(may)

jfmam.dropna()

full_dataset = jfmam.append(jun)

full_dataset.dropna()

full_dataset.columns = ['tripduration', 'starttime', 'stoptime', 'start_stationid', 'start_stationname', 'start_stationlat', 'start_stationlon', 'end_stationid', 'end_stationname', 'end_stationlat', 'end_stationlon', 'bikeid', 'usertype', 'birthyear', 'gender']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d9a05d1223f8> in <module>
#      19 full_dataset.dropna()
#      20
# ---> 21 full_dataset.columns = ['tripduration', 'starttime', 'stoptime', 'start_stationid', 'start_stationname', 'start_stationlat', 'start_stationlon', 'end_stationid', 'end_stationname', 'end_stationlat', 'end_stationlon', 'bikeid', 'usertype', 'birthyear', 'gender']
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5152         try:
#    5153             object.__getattribute__(self, name)
# -> 5154             return object.__setattr__(self, name, value)
#    5155         except AttributeError:
#    5156             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     225         if new_len != old_len:
#     226             raise ValueError(
# --> 227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#     229             )
#
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 15 elements
